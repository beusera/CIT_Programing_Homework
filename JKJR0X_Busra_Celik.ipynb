# %%
# !git clone https://github.com/beusera/CIT_Programing_Homework.git
# Out:
# Cloning into 'CIT_Programing_Homework'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd CIT_Programing_Homework
# Out:
# /content/CIT_Programing_Homework/CIT_Programing_Homework/CIT_Programing_Homework

# %%
with open("my_notes.txt", "w") as file:
    file.write("Mrs. Tevesz Judit\n")
    file.write("My name is Busra Celik.\n")
    file.write("This is my homework for first step\n")

# %%
# !git config --global user.name "beusera"
# !git config --global user.email "celikkbbusra@gmail.com"

# %%
# !git add .

# %%
# !git commit -m "Added notes file from Colab"
# Out:
# [main 6ec68a3] Added notes file from Colab
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# !git push https://beusera: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@github.com/beusera/CIT_Programing_Homework.git
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 362 bytes | 362.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/beusera/CIT_Programing_Homework.git
#    aac81f8..6ec68a3  main -> main

# %%
# !git pull
# Out:
# From https://github.com/beusera/CIT_Programing_Homework
#    aac81f8..6ec68a3  main       -> origin/main
# Already up to date.
